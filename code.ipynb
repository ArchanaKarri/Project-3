# %%
# Dependencies and Setup
import pandas as pd
import pandas as geek

# File to Load (Remember to Change These)
production_data_to_load = "Resources/shipment_data_2021-2022_financial_year.csv"


# Production data reading  and store into Pandas DataFrames
production_data_df = pd.read_csv(production_data_to_load)
# Out:
# C:\Users\archa\AppData\Local\Temp\ipykernel_26856\4085742166.py:10: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   production_data_df = pd.read_csv(production_data_to_load)

# %%
#Displaying the DataFrame
production_data_df.head()
# Out:
#   smpPlantID smlPartWarehouseLocationID         smlCreatedDate  smlShipmentID  \
# 0        P01                        P01  23/07/2021 4:41:16 PM         129241
# 1        P01                        P01  23/07/2021 4:41:16 PM         129241
# 2        P02                        P02  23/07/2021 4:46:47 PM         129243
# 3        P02                        P02  23/07/2021 4:46:47 PM         129243
# 4        P09                        P09  26/07/2021 6:35:23 AM         129247
#
#    smlShipmentLineID smlPartID  \
# 0                  1    105689
# 1                  2    105689
# 2                  1    301717
# 3                  2    301718
# 4                  1    305834
#
#                                       smlDescription smlPartRevisionID  \
# 0  Cardboard Carton Dc/Rsc 1190mm x 195mm x 700mm...               NaN
# 1  Cardboard Carton Dc/Rsc 1190mm x 195mm x 700mm...               NaN
# 2               2 Way Pallet 1120mm x 1120mm x 150mm               P02
# ...

# %%
# Data types od all columns in the DataFrame
production_data_df.dtypes
# Out:
# smpPlantID                     object
# smlPartWarehouseLocationID     object
# smlCreatedDate                 object
# smlShipmentID                   int64
# smlShipmentLineID               int64
# smlPartID                      object
# smlDescription                 object
# smlPartRevisionID              object
# smlQuantityShipped            float64
# smlJobQuantityShipped         float64
# smpCustomerOrganizationID      object
# smpShipDate                    object
# smpShipOrganizationID          object
# smpShipLocationID              object
# smpReversed                      bool
# smpReversalEntry                 bool
# impPartGroupID                 object
# cmlOrganizationID              object
# cmlName                        object
# cmlAddressLine1                object
# cmlCity                        object
# cmlState                       object
# cmlPostCode                    object
# dtype: object

# %%
#dropping rows with null values in smpPlantID,smlPartWarehouseLocationID, impPartGroupID
prod_data_df = production_data_df.dropna(subset=['smpPlantID','smlPartWarehouseLocationID', 'impPartGroupID'])

# %%
prod_data_df
# Out:
#       smpPlantID smlPartWarehouseLocationID         smlCreatedDate  \
# 0            P01                        P01  23/07/2021 4:41:16 PM
# 1            P01                        P01  23/07/2021 4:41:16 PM
# 2            P02                        P02  23/07/2021 4:46:47 PM
# 3            P02                        P02  23/07/2021 4:46:47 PM
# 4            P09                        P09  26/07/2021 6:35:23 AM
# ...          ...                        ...                    ...
# 41731        P11                        P11  26/07/2022 3:38:03 PM
# 41732        P11                        P11  26/07/2022 3:40:09 PM
# 41733        P11                        P11  26/07/2022 3:43:23 PM
# 41734        P11                        P11  26/07/2022 3:53:29 PM
# 41735        P11                        P11  28/07/2022 2:22:13 PM
#
#        smlShipmentID  smlShipmentLineID smlPartID  \
# 0             129241                  1    105689
# 1             129241                  2    105689
# ...

# %%
# Adding SmlQuantityShipped and smlJobQuantityShipped into another column
prod_data_df['quantityShipped']=prod_data_df['smlQuantityShipped']+prod_data_df['smlJobQuantityShipped']

# %%
prod_data_df
# Out:
#       smpPlantID smlPartWarehouseLocationID         smlCreatedDate  \
# 0            P01                        P01  23/07/2021 4:41:16 PM
# 1            P01                        P01  23/07/2021 4:41:16 PM
# 2            P02                        P02  23/07/2021 4:46:47 PM
# 3            P02                        P02  23/07/2021 4:46:47 PM
# 4            P09                        P09  26/07/2021 6:35:23 AM
# ...          ...                        ...                    ...
# 41731        P11                        P11  26/07/2022 3:38:03 PM
# 41732        P11                        P11  26/07/2022 3:40:09 PM
# 41733        P11                        P11  26/07/2022 3:43:23 PM
# 41734        P11                        P11  26/07/2022 3:53:29 PM
# 41735        P11                        P11  28/07/2022 2:22:13 PM
#
#        smlShipmentID  smlShipmentLineID smlPartID  \
# 0             129241                  1    105689
# 1             129241                  2    105689
# ...

# %%
#Dropping the columns smlQuantityShipped , smlJobQuantityShipped as their sum is already stored
prod_data_df_new=prod_data_df.drop(columns=['smlQuantityShipped','smlJobQuantityShipped'])

# %%
prod_data_df_new
# Out:
#       smpPlantID smlPartWarehouseLocationID         smlCreatedDate  \
# 0            P01                        P01  23/07/2021 4:41:16 PM
# 1            P01                        P01  23/07/2021 4:41:16 PM
# 2            P02                        P02  23/07/2021 4:46:47 PM
# 3            P02                        P02  23/07/2021 4:46:47 PM
# 4            P09                        P09  26/07/2021 6:35:23 AM
# ...          ...                        ...                    ...
# 41731        P11                        P11  26/07/2022 3:38:03 PM
# 41732        P11                        P11  26/07/2022 3:40:09 PM
# 41733        P11                        P11  26/07/2022 3:43:23 PM
# 41734        P11                        P11  26/07/2022 3:53:29 PM
# 41735        P11                        P11  28/07/2022 2:22:13 PM
#
#        smlShipmentID  smlShipmentLineID smlPartID  \
# 0             129241                  1    105689
# 1             129241                  2    105689
# ...

# %%
df_new = prod_data_df_new.drop(prod_data_df_new[(prod_data_df_new['smpReversed']==True) | (prod_data_df_new['smpReversalEntry']==True)].index)

# %%
df_new
# Out:
#       smpPlantID smlPartWarehouseLocationID         smlCreatedDate  \
# 0            P01                        P01  23/07/2021 4:41:16 PM
# 1            P01                        P01  23/07/2021 4:41:16 PM
# 2            P02                        P02  23/07/2021 4:46:47 PM
# 3            P02                        P02  23/07/2021 4:46:47 PM
# 4            P09                        P09  26/07/2021 6:35:23 AM
# ...          ...                        ...                    ...
# 41729        P07                        P07  01/07/2022 7:16:33 AM
# 41730        P07                        P07  01/07/2022 8:06:32 AM
# 41733        P11                        P11  26/07/2022 3:43:23 PM
# 41734        P11                        P11  26/07/2022 3:53:29 PM
# 41735        P11                        P11  28/07/2022 2:22:13 PM
#
#        smlShipmentID  smlShipmentLineID smlPartID  \
# 0             129241                  1    105689
# 1             129241                  2    105689
# ...

# %%
# Removing columns smlPartWarehouseLocationID, smpReversed,smpReversalEntry,smpShipLocationID from the dataframe
df_new=df_new.drop(columns=['smlPartWarehouseLocationID','smpReversed','smpReversalEntry','smpShipLocationID'])

# %%
df_new.dtypes
# Out:
# smpPlantID                    object
# smlCreatedDate                object
# smlShipmentID                  int64
# smlShipmentLineID              int64
# smlPartID                     object
# smlDescription                object
# smlPartRevisionID             object
# smpCustomerOrganizationID     object
# smpShipDate                   object
# smpShipOrganizationID         object
# impPartGroupID                string
# cmlOrganizationID             object
# cmlName                       object
# cmlAddressLine1               object
# cmlCity                       object
# cmlState                      object
# cmlPostCode                   object
# quantityShipped              float64
# dtype: object

# %%
# Converting 'impPartGroupID' data type to String
df_new['impPartGroupID']  = df_new['impPartGroupID'] .astype("string")
#Filtering data from 'impPartGroupID' with few selected values into df_new_clean dataframe
df_new_clean = df_new.loc[(df_new['impPartGroupID']=="BED") | (df_new['impPartGroupID'] =="BINS") |(df_new['impPartGroupID'] =="BULK") |(df_new['impPartGroupID'] =="CARD") |(df_new['impPartGroupID'] =="CASE") |(df_new['impPartGroupID'] =="PAL") |(df_new['impPartGroupID'] =="PAL2") |(df_new['impPartGroupID'] =="PEN") ]

# %%
df_new_clean
# Out:
#       smpPlantID         smlCreatedDate  smlShipmentID  smlShipmentLineID  \
# 0            P01  23/07/2021 4:41:16 PM         129241                  1
# 1            P01  23/07/2021 4:41:16 PM         129241                  2
# 2            P02  23/07/2021 4:46:47 PM         129243                  1
# 3            P02  23/07/2021 4:46:47 PM         129243                  2
# 4            P09  26/07/2021 6:35:23 AM         129247                  1
# ...          ...                    ...            ...                ...
# 41729        P07  01/07/2022 7:16:33 AM         155221                  1
# 41730        P07  01/07/2022 8:06:32 AM         155228                  1
# 41733        P11  26/07/2022 3:43:23 PM         156709                  1
# 41734        P11  26/07/2022 3:53:29 PM         156711                  1
# 41735        P11  28/07/2022 2:22:13 PM         156889                  1
#
#       smlPartID                                     smlDescription  \
# ...

# %%
# Writing the result into Clean.csv file
df_new_clean.to_csv('clean.csv')

# %%
# Dependencies
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os


# Google developer API key
from api_keys import g_key

#configure gmaps
gmaps.configure(api_key=g_key)

address=pd.DataFrame(df_new_clean['cmlCity'].unique())

# %%
address.head(10)
# Out:
#                 0
# 0       Bangholme
# 1  Laverton North
# 2  North Richmond
# 3  Baulkham Hills
# 4  Wetherill Park
# 5       Greenbank
# 6    Tullarmarine
# 7       Riverview
# 8     Castle Hill
# 9         Chakola

# %%
#Testing
# set up a parameters dictionary
params = {
    "key": g_key,
    "address" :address
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
#Testing
# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyAF5VAmdew9lJDqEOyccQeL_KBfnqq26MI&address=0

# %%
#testing

# set up lists to hold reponse info
lat = []
lng = []
address=df_new_clean['cmlCity'].unique()
# Loop through the list of cities and perform a request for data on each
for city in address:
 response = requests.get(base_url, params = params).json()
response.keys()
if response ["status"] == "OK":
     geometry = response["results"][0]["geometry"]
print(geometry)

print(f"The latitude information received is: {lat}")
print(f"The longitude information received is: {lng}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\archa\OneDrive\Desktop\homework\Project-3\code.ipynb Cell 21 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/archa/OneDrive/Desktop/homework/Project-3/code.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> # Loop through the list of cities and perform a request for data on each
#       <a href='vscode-notebook-cell:/c%3A/Users/archa/OneDrive/Desktop/homework/Project-3/code.ipynb#X25sZmlsZQ%3D%3D?line=5'>6</a> for city in address:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/archa/OneDrive/Desktop/homework/Project-3/code.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a>  response = requests.get(base_url, params = params).json()
#       <a href='vscode-notebook-cell:/c%3A/Users/archa/OneDrive/Desktop/homework/Project-3/code.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a> response.keys()
# ...

# %%
df_address['address']=pd.DataFrame(df_new_clean['cmlAddressLine1'] +','+ df_new_clean['cmlCity'] +' ,'+df_new_clean['cmlState'])
df_address
from googlemaps import Client as GoogleMaps
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\archa\OneDrive\Desktop\homework\Project-3\code.ipynb Cell 22 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/archa/OneDrive/Desktop/homework/Project-3/code.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> df_address['address']=pd.DataFrame(df_new_clean['cmlAddressLine1'] +','+ df_new_clean['cmlCity'] +' ,'+df_new_clean['cmlState'])
#       <a href='vscode-notebook-cell:/c%3A/Users/archa/OneDrive/Desktop/homework/Project-3/code.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> df_address
# ----> <a href='vscode-notebook-cell:/c%3A/Users/archa/OneDrive/Desktop/homework/Project-3/code.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> from googlemaps import Client as GoogleMaps
#
# ModuleNotFoundError: No module named 'googlemaps'

# %%
df_address['long'] = ""
df_address['lat'] = ""

# %%
df_address
# Out:
#                                                  0  \
# 0           Door 3, 55 Letcon Drive,Bangholme ,VIC
# 1           Door 3, 55 Letcon Drive,Bangholme ,VIC
# 2                      Door 12,Laverton North ,VIC
# 3                      Door 12,Laverton North ,VIC
# 4      Gate 1, Beaumont Avenue,North Richmond ,NSW
# ...                                            ...
# 41729                   PO Box 1237,Dandenong ,VIC
# 41730                   PO Box 1237,Dandenong ,VIC
# 41733                      Wilhelm Road,Murtho ,SA
# 41734                      Wilhelm Road,Murtho ,SA
# 41735        PO Box 16126,Collins Street West ,VIC
#
#                                            address long lat
# 0           Door 3, 55 Letcon Drive,Bangholme ,VIC
# 1           Door 3, 55 Letcon Drive,Bangholme ,VIC
# 2                      Door 12,Laverton North ,VIC
# 3                      Door 12,Laverton North ,VIC
# 4      Gate 1, Beaumont Avenue,North Richmond ,NSW
# ...

# %%
for x in df_address:
    try:
        time.sleep(1) #to add delay in case of large DFs
        geocode_result = gmaps.geocode(df_address['address'][x])
        df_address['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
        df_address['long'][x] = geocode_result[0]['geometry']['location']['lng']
    except IndexError:
        print("Address was wrong...")
    except Exception as e:
        print("Unexpected error occurred.", e )
df_address.head()


geocode_result
# Out:
# Unexpected error occurred. name 'time' is not defined
# Unexpected error occurred. name 'time' is not defined
# Unexpected error occurred. name 'time' is not defined
# Unexpected error occurred. name 'time' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\archa\OneDrive\Desktop\homework\Project-3\code.ipynb Cell 25 in <cell line: 14>()
#      <a href='vscode-notebook-cell:/c%3A/Users/archa/OneDrive/Desktop/homework/Project-3/code.ipynb#X41sZmlsZQ%3D%3D?line=9'>10</a>         print("Unexpected error occurred.", e )
#      <a href='vscode-notebook-cell:/c%3A/Users/archa/OneDrive/Desktop/homework/Project-3/code.ipynb#X41sZmlsZQ%3D%3D?line=10'>11</a> df_address.head()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/archa/OneDrive/Desktop/homework/Project-3/code.ipynb#X41sZmlsZQ%3D%3D?line=13'>14</a> geocode_result
#
# ...

# %%
df['address']=df_new_clean['cmlAddressLine1']+ df_new_clean['cmlCity']
for x in range(len(address)):
    try:
        time.sleep(1) #to add delay in case of large DFs
        geocode_result = gmaps.geocode(addresses['FullAddress'][x])
        addresses['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
        addresses['long'][x] = geocode_result[0]['geometry']['location']['lng']
    except IndexError:
        print("Address was wrong...")
    except Exception as e:
        print("Unexpected error occurred.", e )
addresses.head()
