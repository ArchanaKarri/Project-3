# %%
# Dependencies and Setup
import pandas as pd
import pandas as geek

# File to Load (Remember to Change These)
production_data_to_load = "Resources/shipment_data_2021-2022_financial_year.csv"


# Read School and Student Data File and store into Pandas DataFrames
production_data_df = pd.read_csv(production_data_to_load)
# Out:
# C:\Users\archa\AppData\Local\Temp\ipykernel_26856\1879351707.py:10: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   production_data_df = pd.read_csv(production_data_to_load)

# %%
production_data_df.head()
# Out:
#   smpPlantID smlPartWarehouseLocationID         smlCreatedDate  smlShipmentID  \
# 0        P01                        P01  23/07/2021 4:41:16 PM         129241
# 1        P01                        P01  23/07/2021 4:41:16 PM         129241
# 2        P02                        P02  23/07/2021 4:46:47 PM         129243
# 3        P02                        P02  23/07/2021 4:46:47 PM         129243
# 4        P09                        P09  26/07/2021 6:35:23 AM         129247
#
#    smlShipmentLineID smlPartID  \
# 0                  1    105689
# 1                  2    105689
# 2                  1    301717
# 3                  2    301718
# 4                  1    305834
#
#                                       smlDescription smlPartRevisionID  \
# 0  Cardboard Carton Dc/Rsc 1190mm x 195mm x 700mm...               NaN
# 1  Cardboard Carton Dc/Rsc 1190mm x 195mm x 700mm...               NaN
# 2               2 Way Pallet 1120mm x 1120mm x 150mm               P02
# ...

# %%
production_data_df.count()
# Out:
# smpPlantID                    41736
# smlPartWarehouseLocationID    41698
# smlCreatedDate                41736
# smlShipmentID                 41736
# smlShipmentLineID             41736
# smlPartID                     41736
# smlDescription                41736
# smlPartRevisionID             25002
# smlQuantityShipped            41736
# smlJobQuantityShipped         41736
# smpCustomerOrganizationID     41736
# smpShipDate                   41736
# smpShipOrganizationID         41736
# smpShipLocationID             28032
# smpReversed                   41736
# smpReversalEntry              41736
# impPartGroupID                41698
# cmlOrganizationID             41554
# cmlName                       41554
# cmlAddressLine1               41425
# cmlCity                       41081
# cmlState                      40839
# cmlPostCode                   37710
# dtype: int64

# %%
prod_data_df = production_data_df.dropna(subset=['smpPlantID', 'impPartGroupID'])

# %%
prod_data_df
# Out:
#       smpPlantID smlPartWarehouseLocationID         smlCreatedDate  \
# 0            P01                        P01  23/07/2021 4:41:16 PM
# 1            P01                        P01  23/07/2021 4:41:16 PM
# 2            P02                        P02  23/07/2021 4:46:47 PM
# 3            P02                        P02  23/07/2021 4:46:47 PM
# 4            P09                        P09  26/07/2021 6:35:23 AM
# ...          ...                        ...                    ...
# 41731        P11                        P11  26/07/2022 3:38:03 PM
# 41732        P11                        P11  26/07/2022 3:40:09 PM
# 41733        P11                        P11  26/07/2022 3:43:23 PM
# 41734        P11                        P11  26/07/2022 3:53:29 PM
# 41735        P11                        P11  28/07/2022 2:22:13 PM
#
#        smlShipmentID  smlShipmentLineID smlPartID  \
# 0             129241                  1    105689
# 1             129241                  2    105689
# ...

# %%
prod_data_df['quantityShipped']=prod_data_df['smlQuantityShipped']+prod_data_df['smlJobQuantityShipped']
# Out:
# C:\Users\archa\AppData\Local\Temp\ipykernel_26856\3293638088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod_data_df['quantityShipped']=prod_data_df['smlQuantityShipped']+prod_data_df['smlJobQuantityShipped']

# %%
prod_data_df
# Out:
#       smpPlantID smlPartWarehouseLocationID         smlCreatedDate  \
# 0            P01                        P01  23/07/2021 4:41:16 PM
# 1            P01                        P01  23/07/2021 4:41:16 PM
# 2            P02                        P02  23/07/2021 4:46:47 PM
# 3            P02                        P02  23/07/2021 4:46:47 PM
# 4            P09                        P09  26/07/2021 6:35:23 AM
# ...          ...                        ...                    ...
# 41731        P11                        P11  26/07/2022 3:38:03 PM
# 41732        P11                        P11  26/07/2022 3:40:09 PM
# 41733        P11                        P11  26/07/2022 3:43:23 PM
# 41734        P11                        P11  26/07/2022 3:53:29 PM
# 41735        P11                        P11  28/07/2022 2:22:13 PM
#
#        smlShipmentID  smlShipmentLineID smlPartID  \
# 0             129241                  1    105689
# 1             129241                  2    105689
# ...

# %%
prod_data_df_new=prod_data_df.drop(columns=['smlQuantityShipped','smlJobQuantityShipped'])

# %%
prod_data_df_new
# Out:
#       smpPlantID smlPartWarehouseLocationID         smlCreatedDate  \
# 0            P01                        P01  23/07/2021 4:41:16 PM
# 1            P01                        P01  23/07/2021 4:41:16 PM
# 2            P02                        P02  23/07/2021 4:46:47 PM
# 3            P02                        P02  23/07/2021 4:46:47 PM
# 4            P09                        P09  26/07/2021 6:35:23 AM
# ...          ...                        ...                    ...
# 41731        P11                        P11  26/07/2022 3:38:03 PM
# 41732        P11                        P11  26/07/2022 3:40:09 PM
# 41733        P11                        P11  26/07/2022 3:43:23 PM
# 41734        P11                        P11  26/07/2022 3:53:29 PM
# 41735        P11                        P11  28/07/2022 2:22:13 PM
#
#        smlShipmentID  smlShipmentLineID smlPartID  \
# 0             129241                  1    105689
# 1             129241                  2    105689
# ...

# %%
#prod_data_df.drop(['smpReversed']== True)
#prod_data_df_clean=prod_data_df.drop((prod_data_df['smpReversed']==True) & (prod_data_df['smpReversalEntry']==True), inplace=True)
df_new = prod_data_df_new.drop(prod_data_df_new[(prod_data_df_new['smpReversed']==True) & (prod_data_df_new['smpReversalEntry']==True)].index)
print(df_new)
# Out:
#       smpPlantID smlPartWarehouseLocationID         smlCreatedDate  \
# 0            P01                        P01  23/07/2021 4:41:16 PM
# 1            P01                        P01  23/07/2021 4:41:16 PM
# 2            P02                        P02  23/07/2021 4:46:47 PM
# 3            P02                        P02  23/07/2021 4:46:47 PM
# 4            P09                        P09  26/07/2021 6:35:23 AM
# ...          ...                        ...                    ...
# 41731        P11                        P11  26/07/2022 3:38:03 PM
# 41732        P11                        P11  26/07/2022 3:40:09 PM
# 41733        P11                        P11  26/07/2022 3:43:23 PM
# 41734        P11                        P11  26/07/2022 3:53:29 PM
# 41735        P11                        P11  28/07/2022 2:22:13 PM
#
#        smlShipmentID  smlShipmentLineID smlPartID  \
# 0             129241                  1    105689
# 1             129241                  2    105689
# ...

# %%
df_new
# Out:
#       smpPlantID smlPartWarehouseLocationID         smlCreatedDate  \
# 0            P01                        P01  23/07/2021 4:41:16 PM
# 1            P01                        P01  23/07/2021 4:41:16 PM
# 2            P02                        P02  23/07/2021 4:46:47 PM
# 3            P02                        P02  23/07/2021 4:46:47 PM
# 4            P09                        P09  26/07/2021 6:35:23 AM
# ...          ...                        ...                    ...
# 41731        P11                        P11  26/07/2022 3:38:03 PM
# 41732        P11                        P11  26/07/2022 3:40:09 PM
# 41733        P11                        P11  26/07/2022 3:43:23 PM
# 41734        P11                        P11  26/07/2022 3:53:29 PM
# 41735        P11                        P11  28/07/2022 2:22:13 PM
#
#        smlShipmentID  smlShipmentLineID smlPartID  \
# 0             129241                  1    105689
# 1             129241                  2    105689
# ...

# %%
df_new=df_new.drop(columns=['smpReversed','smpReversalEntry',''])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#clean_df_groupdf=clean_df.groupby('smpPlantID')

# %%
#clean_df_groupdf.head()
# Out:
#       smpPlantID smlPartWarehouseLocationID          smlCreatedDate  \
# 11           P13                        P13   26/07/2021 7:05:43 AM
# 16           P07                        P07   26/07/2021 7:25:46 AM
# 19           P03                        P03   26/07/2021 7:35:56 AM
# 22           P07                        P07   26/07/2021 7:50:58 AM
# 23           P12                        P12   26/07/2021 7:53:22 AM
# ...          ...                        ...                     ...
# 19780        P14                        P14   07/12/2021 7:52:09 AM
# 19781        P14                        P14   07/12/2021 7:52:09 AM
# 19796        P14                        P14  07/12/2021 10:06:10 AM
# 20508        P14                        P14   13/12/2021 7:27:44 AM
# 22535        P06                        P06   10/01/2022 3:44:11 PM
#
#        smlShipmentID  smlShipmentLineID smlPartID  \
# 11            129681                  1    303638
# ...

# %%
clean_df.to_csv('clean.csv')
